# %% [markdown]
# ## Windows Powershell
# `Get-Help`
# `Get-Alias`
# `Get-ChildItem C:\`
# `sls <string> <fiilename>` or `Select-String <string> <filename>`
# `ls C:\ -Recurse -Filter <file>`

# %% [markdown]
# `echo woof > dog.txt`
# `rm service 2> $null` Filter out error messsage
# `Get-Help about_redirection`
# `Get-LocalUser`
# `Get-LocalGroup`
# `Get-LocalGroupMember <groupname>`
# `net user <user> /logonpasswordchg:yes` // change user password
# `net user <user> /add /logonpasswordchg:yes`
# `net user <user> /delete`

# %% [markdown]
# ## Linux
# `rm service > /dev/null` Filter out error message
# `mkdir -p -m -v`  -p allow to create parent, -m set permission
# `passwd -e <user>` force user to change password next time he login
# `sudo useradd <user>`
# `sudo userdelete <user>`

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## WIndows File Permissions
# - ACL - Access COntrol List
# - DACL - Discretionary Access COntrol List - as a note about who can use the file and what they allowed to do with it
# - SACL - System Access Control List - tell windows to use event log everytime someone access a file or folder
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)
# ![image-6.png](attachment:image-6.png)
# ![image-7.png](attachment:image-7.png)
# ![image-9.png](attachment:image-9.png)
# ![image-10.png](attachment:image-10.png)
# ![image-11.png](attachment:image-11.png)
# - to view and change ACL:
#     - `icacls <file>`
#     - `icacls /?` show helps
#     - `icacls '<file path>' /grant 'Everyone:(OI)(CI)(R)'`
#     - `icacls '<file path>' /remove Everyone`
# - Special permission
# ![image-8.png](attachment:image-8.png)

# %% [markdown]
# ## Linux FIle Permission
# ![image.png](attachment:image.png)
# - first - is file, dr is directory
# - -rwx - file permission of the owner
# - rw- - file permission of group
# - r-- file permisson of all other users
#
# `chmod u+x <file>`
#  - u for owner
#  - g for group
#  - o other user
#
#  `chmod 777 <file>`
#  - r,w,x 7
#  - r 4
#  - w 2
#  - x 1
#  - \- 0
#
#  - Special Permission
#      - setuid // run root priveledge file without sudo
#      ![image-2.png](attachment:image-2.png)
#      - setgid // enable the file to run as group member
#      ![image-3.png](attachment:image-3.png)
#      - sticky bit // make anyone can write to a file or folder but cant delete anything. only owner can delete the content
#      ![image-4.png](attachment:image-4.png)

# %% [markdown]
# `chown <user>` change owner
